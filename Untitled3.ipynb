# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
cd ..
# Out:
# /Users/alistairwalsh/Documents/git_repos

# %%
# !pwd
# Out:
# /Users/alistairwalsh/Documents/git_repos

# %%
# !ls
# Out:
# 2019_11_14_Monash.ipynb            mbox-short.txt
# 5_questions_and_AQ.ipynb           metadata.pdf
# Day_2.ipynb                        numpy_pandas
# Pandas_sql.md                      pandas_model.pdf
# Untitled.ipynb                     pdf_extract.ipynb
# Untitled1.ipynb                    pelican_site
# Untitled2.ipynb                    presidents_lies_web_scraping.ipynb
# Untitled3.ipynb                    titanic
# __pycache__                        titanic.rtf
# exercises                          titanic.txt
# mbox-short.ipynb                   titanic.zip

# %%
cd titanic/
# Out:
# /Users/alistairwalsh/Documents/git_repos/2019_11_7_Monash_Python/titanic

# %%
pwd
# Out:
# '/Users/alistairwalsh/Documents/git_repos/2019_11_7_Monash_Python/titanic'

# %%
ls
# Out:
# gender_submission.csv* test.csv*              train.csv*

# %%
ls /Users/alistairwalsh/Downloads/titanic
# Out:
# AQ _Responses.csv
# AQ _Responses_no_email.csv
# AQ_Nov_2019.csv
# AQ_copy.csv
# AQ_responses.csv
# Authorize_2249-3563-BF64-628E-01D9-B44C.auz
# Autism Q automate (Responses) - Form responses 1.csv
# BTCMarkets_BTCAUD_1h.csv
# BTCMarkets_BTCAUD_d.csv
# BloodChemistry/
# BloodChemistry.zip
# Data-Science 101 (Responses) - Form responses.csv
# DrumMachines_v8.3/
# DrumMachines_v8.3.zip
# EndOfStudy.zip
# Exploring_Kubernetes.pdf
# FreeCAD_0.18-16146-OSX-x86_64-conda-Qt5-Py3.dmg
# MIDIchoir30.zip
# Mr.Robot.S04E04.720p.WEB.x264-XLF[rarbg]/
# Mr.Robot.S04E05.720p.WEB.x264-XLF[TGx]/
# Mr.Robot.S04E06.WEB.x264-XLF[ettv]/
# Mr.Robot.S04E07.1080p.WEB.x264-XLF[TGx]/
# Mr.Robot.S04E08.1080p.WEB.x264-XLF[TGx]/
# Mr.Robot.S04E09.1080p.WEB.h264-TBS[TGx]/
# Mr.Robot.S04E10.1080p.WEB.h264-TRUMP[TGx]/
# Mr.Robot.S04E11.1080p.WEB.x264-XLF[TGx]/
# Mr.Robot.S04E12.1080p.WEB.h264-TBS[TGx]/
# Mr.Robot.S04E13.1080p.WEB.h264-TBS[TGx]/
# ...

# %%
train = pd.read_csv('/Users/alistairwalsh/Documents/git_repos/2019_11_7_Monash_Python/titanic/train.csv')

# %%
pwd
# Out:
# '/Users/alistairwalsh/Documents/git_repos'

# %%
cd 2019_11_7_Monash_Python/
# Out:
# /Users/alistairwalsh/Documents/git_repos/2019_11_7_Monash_Python

# %%
cd titanic/
# Out:
# /Users/alistairwalsh/Documents/git_repos/2019_11_7_Monash_Python/titanic

# %%
pwd
# Out:
# '/Users/alistairwalsh/Documents/git_repos/2019_11_7_Monash_Python/titanic'

# %%
ls
# Out:
# gender_submission.csv* test.csv*              train.csv*

# %%
test = pd.read_csv('test.csv')

# %%
gender = pd.read_csv('gender_submission.csv')

# %%
gender
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
test
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
seaborn_titanic = sns.load_dataset('titanic')

# %%
seaborn_titanic.shape
# Out:
# (891, 15)

# %%
seaborn_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.drop(columns = ['Cabin'], inplace= True)

# %%
train.columns = [c.lower() for c in train.columns]

# %%
train.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'embarked'],
#       dtype='object')

# %%
train[train['age'].isna()]
# Out:
#      passengerid  survived  pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
train[['age','fare']].corr()
# Out:
#            age      fare
# age   1.000000  0.096067
# fare  0.096067  1.000000

# %%
def get_prefix(x):
    return x.split(',')[1].split()[0]

train['prefix'] = train['name'].apply(get_prefix)

# %%
train['prefix'].value_counts()
# Out:
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# Mme.           1
# Don.           1
# Ms.            1
# Sir.           1
# Jonkheer.      1
# Lady.          1
# Capt.          1
# the            1
# Name: prefix, dtype: int64

# %%
train[['prefix','age']][train['age'].isna()]
# Out:
#       prefix  age
# 5        Mr.  NaN
# 17       Mr.  NaN
# 19      Mrs.  NaN
# 26       Mr.  NaN
# 28     Miss.  NaN
# 29       Mr.  NaN
# 31      Mrs.  NaN
# 32     Miss.  NaN
# 36       Mr.  NaN
# 42       Mr.  NaN
# 45       Mr.  NaN
# 46       Mr.  NaN
# 47     Miss.  NaN
# 48       Mr.  NaN
# 55       Mr.  NaN
# 64       Mr.  NaN
# 65   Master.  NaN
# 76       Mr.  NaN
# 77       Mr.  NaN
# 82     Miss.  NaN
# 87       Mr.  NaN
# 95       Mr.  NaN
# 101      Mr.  NaN
# 107      Mr.  NaN
# 109    Miss.  NaN
# 121      Mr.  NaN
# 126      Mr.  NaN
# 128    Miss.  NaN
# 140     Mrs.  NaN
# 154      Mr.  NaN
# ..       ...  ...
# 718      Mr.  NaN
# 727    Miss.  NaN
# 732      Mr.  NaN
# 738      Mr.  NaN
# 739      Mr.  NaN
# 740      Mr.  NaN
# 760      Mr.  NaN
# 766      Dr.  NaN
# 768      Mr.  NaN
# 773      Mr.  NaN
# 776      Mr.  NaN
# 778      Mr.  NaN
# 783      Mr.  NaN
# 790      Mr.  NaN
# 792    Miss.  NaN
# 793      Mr.  NaN
# 815      Mr.  NaN
# 825      Mr.  NaN
# ...

# %%
train[train['prefix'] == 'Master.']['age'].median()
# Out:
# 3.5

# %%
train = pd.read_csv('train.csv')
train.columns = [c.lower() for c in train.columns]

def get_prefix(x):
    return x.split(',')[1].split()[0]

train['prefix'] = train['name'].apply(get_prefix)

train['age'][(train['prefix'] == 'Master.') & (train['age'].isna())]\
= train[train['prefix'] == 'Master.']['age'].median()

train['age'][(train['prefix'] == 'Mr.') & (train['age'].isna())] \
= train[train['prefix'] == 'Mr.']['age'].median()

train['age'][(train['prefix'] == 'Miss.') & (train['age'].isna())] \
= train[train['prefix'] == 'Miss.']['age'].median()

train['age'][(train['prefix'] == 'Mrs.') & (train['age'].isna())] \
= train[train['prefix'] == 'Mrs.']['age'].median()
# Out:
# /Users/alistairwalsh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/alistairwalsh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /Users/alistairwalsh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
train[train['age'].isna()]
# Out:
#      passengerid  survived  pclass                       name   sex  age  \
# 766          767         0       1  Brewe, Dr. Arthur Jackson  male  NaN
#
#      sibsp  parch  ticket  fare cabin embarked prefix
# 766      0      0  112379  39.6   NaN        C    Dr.

# %%
train[train['prefix'] == 'Dr.']
# Out:
#      passengerid  survived  pclass                           name     sex  \
# 245        246.0       0.0     1.0    Minahan, Dr. William Edward    male
# 317        318.0       0.0     2.0           Moraweck, Dr. Ernest    male
# 398        399.0       0.0     2.0               Pain, Dr. Alfred    male
# 632        633.0       1.0     1.0      Stahelin-Maeglin, Dr. Max    male
# 660        661.0       1.0     1.0  Frauenthal, Dr. Henry William    male
# 766        767.0       0.0     1.0      Brewe, Dr. Arthur Jackson    male
# 796        797.0       1.0     1.0    Leader, Dr. Alice (Farnham)  female
#
#       age  sibsp  parch    ticket      fare embarked prefix
# 245  44.0    2.0    0.0     19928   90.0000        Q    Dr.
# 317  54.0    0.0    0.0     29011   14.0000        S    Dr.
# 398  23.0    0.0    0.0    244278   10.5000        S    Dr.
# 632  32.0    0.0    0.0     13214   30.5000        C    Dr.
# 660  50.0    2.0    0.0  PC 17611  133.6500        S    Dr.
# ...

# %%
train['age'][(train['prefix'] == 'Dr.') & (train['age'].isna())] \
= train[train['prefix'] == 'Dr.']['age'].median()
# Out:
# /Users/alistairwalsh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# passengerid    891 non-null int64
# survived       891 non-null int64
# pclass         891 non-null int64
# name           891 non-null object
# sex            891 non-null object
# age            891 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# ticket         891 non-null object
# fare           891 non-null float64
# cabin          204 non-null object
# embarked       889 non-null object
# prefix         891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
train[train['embarked'].isna()]
# Out:
#      passengerid  survived  pclass                                       name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         sex   age  sibsp  parch  ticket  fare cabin embarked prefix
# 61   female  38.0      0      0  113572  80.0   B28      NaN  Miss.
# 829  female  62.0      0      0  113572  80.0   B28      NaN   Mrs.

# %%
train[['embarked','ticket']].sort_values(by = 'embarked')
# Out:
#     embarked              ticket
# 258        C            PC 17755
# 125        C                2651
# 354        C                2647
# 352        C                2695
# 128        C                2668
# 641        C            PC 17477
# 130        C              349241
# 798        C                2685
# 644        C                2666
# 645        C            PC 17572
# 647        C               13213
# 135        C       SC/PARIS 2133
# 337        C               16966
# 793        C            PC 17600
# 139        C            PC 17593
# 140        C                2678
# 329        C              111361
# 789        C            PC 17593
# 325        C            PC 17760
# 659        C               35273
# 632        C               13214
# 661        C                2623
# 122        C              237736
# 361        C       SC/PARIS 2167
# 96         C            PC 17754
# 97         C            PC 17759
# 620        C                2659
# ...

# %%
train_2 = pd.read_csv('train.csv')

# %%
train_2['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train['embarked'][train['embarked'].isna()] = 'S'
# Out:
# /Users/alistairwalsh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train.drop(columns = ['cabin'], inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# passengerid    891 non-null int64
# survived       891 non-null int64
# pclass         891 non-null int64
# name           891 non-null object
# sex            891 non-null object
# age            891 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# ticket         891 non-null object
# fare           891 non-null float64
# embarked       891 non-null object
# prefix         891 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# passengerid    891 non-null int64
# survived       891 non-null int64
# pclass         891 non-null int64
# name           891 non-null object
# sex            891 non-null object
# age            891 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# ticket         891 non-null object
# fare           891 non-null float64
# embarked       891 non-null object
# prefix         891 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.drop(columns = ['name','passengerid','ticket'],inplace = True)

# %%
train['sex'] = [1 if s == 'male' else 0 for s in train['sex']]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# sex         891 non-null int64
# age         891 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# fare        891 non-null float64
# embarked    891 non-null object
# prefix      891 non-null object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.7+ KB

# %%
prefix = pd.get_dummies(train['prefix'])

# %%
train.join(prefix, axis = 'columns')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-198-f03ca034fd4d> in <module>
# ----> 1 train.join(prefix, axis = 'columns')
#
# TypeError: join() got an unexpected keyword argument 'axis'

# %%
train = pd.concat([train, prefix], axis = 'columns')

# %%
train.drop(columns = 'prefix', inplace = True)

# %%
embarked = pd.get_dummies(train['embarked'])

# %%
train = pd.concat([train, embarked], axis = 'columns')

# %%
train.drop(columns = ['embarked'], inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 27 columns):
# survived     891 non-null int64
# pclass       891 non-null int64
# sex          891 non-null int64
# age          891 non-null float64
# sibsp        891 non-null int64
# parch        891 non-null int64
# fare         891 non-null float64
# Capt.        891 non-null uint8
# Col.         891 non-null uint8
# Don.         891 non-null uint8
# Dr.          891 non-null uint8
# Jonkheer.    891 non-null uint8
# Lady.        891 non-null uint8
# Major.       891 non-null uint8
# Master.      891 non-null uint8
# Miss.        891 non-null uint8
# Mlle.        891 non-null uint8
# Mme.         891 non-null uint8
# Mr.          891 non-null uint8
# Mrs.         891 non-null uint8
# Ms.          891 non-null uint8
# Rev.         891 non-null uint8
# Sir.         891 non-null uint8
# the          891 non-null uint8
# C            891 non-null uint8
# Q            891 non-null uint8
# ...

# %%
X = train.iloc[:,1:]
y = train['survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier(min_samples_split=20, min_samples_leaf=5)
clf = clf.fit(X_train, y_train)

# %%
clf.score(X_train, y_train)
# Out:
# 0.8640939597315436

# %%
clf.score(X_test, y_test)
# Out:
# 0.8033898305084746
